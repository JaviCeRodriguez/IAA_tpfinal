# %%
import os
from dotenv import load_dotenv
import pandas as pd
import spotipy
from tqdm import tqdm
from spotipy.oauth2 import SpotifyClientCredentials

from utils.etl import get_playlist_info, get_track_info, get_tracks_from_playlists

# %%
genres_seeds = [
    "acoustic", "afrobeat", "alt-rock", "alternative", "ambient", "anime", "black-metal", 
    "bluegrass", "blues", "bossanova", "brazil", "breakbeat", "british", "cantopop", 
    "chicago-house", "children", "chill", "classical", "club", "comedy", "country", "dance", 
    "dancehall", "death-metal", "deep-house", "detroit-techno", "disco", "disney", 
    "drum-and-bass", "dub", "dubstep", "edm", "electro", "electronic", "emo", "folk", "forro", 
    "french", "funk", "garage", "german", "gospel", "goth", "grindcore", "groove", "grunge", 
    "guitar", "happy", "hard-rock", "hardcore", "hardstyle", "heavy-metal", "hip-hop", "holidays", 
    "honky-tonk", "house", "idm", "indian", "indie", "indie-pop", "industrial", "iranian", 
    "j-dance", "j-idol", "j-pop", "j-rock", "jazz", "k-pop", "kids", "latin", "latino", "malay", 
    "mandopop", "metal", "metal-misc", "metalcore", "minimal-techno", "movies", "mpb", "new-age", 
    "new-release", "opera", "pagode", "party", "philippines-opm", "piano", "pop", "pop-film", 
    "post-dubstep", "power-pop", "progressive-house", "psych-rock", "punk", "punk-rock", "r-n-b", 
    "rainy-day", "reggae", "reggaeton", "road-trip", "rock", "rock-n-roll", "rockabilly", "romance", 
    "sad", "salsa", "samba", "sertanejo", "show-tunes", "singer-songwriter", "ska", "sleep", 
    "songwriter", "soul", "soundtracks", "spanish", "study", "summer", "swedish", "synth-pop", 
    "tango", "techno", "trance", "trip-hop", "turkish", "work-out", "world-music"
]

# %%
# Spotify API credentials
load_dotenv()
client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')

# %%
# Spotify API authentication
client_credentials_manager = SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret
)
sp = spotipy.Spotify(
    client_credentials_manager=client_credentials_manager
)

# %%
playlists = []

for genre in genres_seeds:
    # Search playlists by genre
    playlists_data = sp.search(q=genre, type='playlist', limit=50, offset=0)
    playlists += [
        get_playlist_info(playlist, genre)
        for playlist in playlists_data['playlists']['items']
    ]

df_playlists = pd.DataFrame(playlists)
print(f'Shape playlists', df_playlists.shape)

# Validation of playlists with null values
print(f'Null in id col of playlists', df_playlists["id"].isna().value_counts())

# Delete rows with null values
df_playlists.dropna(inplace=True)
print(f'Null in id col of playlists', df_playlists["id"].isna().value_counts())

df_playlists.head()
# Out:
# Shape playlists (6279, 5)
# Null in id col of playlists id
# False    6279
# Name: count, dtype: int64
# Null in id col of playlists id
# False    6279
# Name: count, dtype: int64
#                        id                               name
# 0  37i9dQZF1DWUH2AzNQzWua  Acoustic Hits: Oldies but Goodies  \
# 1  37i9dQZF1DWXmlLSKkfdAk                    Acoustic Covers
# 2  37i9dQZF1EIdu0PHOCYQ71                       Acoustic Mix
# 3  37i9dQZF1DWWxrt1tiKYiX                       Acoustic Pop
# 4  4Xv7w5RBLUz71sSzIs4C6b   Acoustic Covers of Popular Songs
#
#                                          tracks_href
# 0  https://api.spotify.com/v1/playlists/37i9dQZF1...  \
# 1  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 2  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 3  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 4  https://api.spotify.com/v1/playlists/4Xv7w5RBL...
#
#                                           main_image     genre
# 0  https://i.scdn.co/image/ab67706f0000000360689d...  acoustic
# 1  https://i.scdn.co/image/ab67706f00000003bd1b35...  acoustic
# 2  https://seed-mix-image.spotifycdn.com/v6/img/d...  acoustic
# 3  https://i.scdn.co/image/ab67706f0000000328ec47...  acoustic
# 4  https://i.scdn.co/image/ab67706c0000bebb5a4a94...  acoustic

# %%
# Get tracks from playlists
tracks_playlists = get_tracks_from_playlists(playlists=df_playlists, sp=sp)
df_tracks = pd.DataFrame(tracks_playlists)
print('Shape tracks:', df_tracks.shape)

# Validation of tracks with null values
print('Null in id col of tracks:', df_tracks["id"].isna().value_counts())

# Delete rows with null values
df_tracks.dropna(inplace=True)
print('Null in id col of tracks:', df_tracks["id"].isna().value_counts())

# Delete duplicates by id
df_tracks.drop_duplicates(subset=["id"], inplace=True)
print('Shape tracks (without duplicates):', df_tracks.shape)
# Out:
# 100%|██████████| 6279/6279 [48:26<00:00,  2.16it/s]
# Shape tracks: (453593, 5)
# Null in id col of tracks: id
# False    453421
# True        172
# Name: count, dtype: int64
# Null in id col of tracks: id
# False    453421
# Name: count, dtype: int64
# Shape tracks (without duplicates): (276579, 5)

# %%
# Save df_tracks to csv
df_tracks.to_csv('./datasets/tracks.csv', index=False)

# %%
# Get audio features from tracks
audio_features = []

for n in tqdm(range(len(df_tracks) // 100 + 1)):
    df_track_pack = df_tracks.iloc[n*100:(n+1)*100]
    audio_features_pack = sp.audio_features(tracks=list(df_track_pack['id']))
    audio_features += audio_features_pack

df_audio_features = pd.DataFrame(audio_features)
print('Shape audio features:', df_audio_features.shape)
# Out:
# 100%|██████████| 2766/2766 [19:46<00:00,  2.33it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 9
#       6     audio_features_pack = sp.audio_features(tracks=list(df_track_pack['id']))
#       7     audio_features += audio_features_pack
# ----> 9 df_audio_features = pd.DataFrame(audio_features)
#      10 print('Shape audio features:', df_audio_features.shape)
#
# File c:\Users\javic\Documents\UNSAM\IAA_tpfinal\venv\Lib\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     780     if columns is not None:
#     781         columns = ensure_index(columns)
# --> 782     arrays, columns, index = nested_data_to_arrays(
#     783         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     784         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     785         data,
#     786         columns,
#     787         index,  # type: ignore[arg-type]
#     788         dtype,
#     789     )
#     790     mgr = arrays_to_mgr(
#     791         arrays,
#     792         columns,
#    (...)
#     795         typ=manager,
#     796     )
#     797 else:
#
# File c:\Users\javic\Documents\UNSAM\IAA_tpfinal\venv\Lib\site-packages\pandas\core\internals\construction.py:498, in nested_data_to_arrays(data, columns, index, dtype)
#     495 if is_named_tuple(data[0]) and columns is None:
#     496     columns = ensure_index(data[0]._fields)
# --> 498 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     499 columns = ensure_index(columns)
#     501 if index is None:
#
# File c:\Users\javic\Documents\UNSAM\IAA_tpfinal\venv\Lib\site-packages\pandas\core\internals\construction.py:832, in to_arrays(data, columns, dtype)
#     830     arr = _list_to_arrays(data)
#     831 elif isinstance(data[0], abc.Mapping):
# --> 832     arr, columns = _list_of_dict_to_arrays(data, columns)
#     833 elif isinstance(data[0], ABCSeries):
#     834     arr, columns = _list_of_series_to_arrays(data, columns)
#
# File c:\Users\javic\Documents\UNSAM\IAA_tpfinal\venv\Lib\site-packages\pandas\core\internals\construction.py:912, in _list_of_dict_to_arrays(data, columns)
#     910     gen = (list(x.keys()) for x in data)
#     911     sort = not any(isinstance(d, dict) for d in data)
# --> 912     pre_cols = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#     913     columns = ensure_index(pre_cols)
#     915 # assure that they are of the base dict class and not of derived
#     916 # classes
#
# File c:\Users\javic\Documents\UNSAM\IAA_tpfinal\venv\Lib\site-packages\pandas\_libs\lib.pyx:374, in pandas._libs.lib.fast_unique_multiple_list_gen()
#
# File c:\Users\javic\Documents\UNSAM\IAA_tpfinal\venv\Lib\site-packages\pandas\core\internals\construction.py:910, in <genexpr>(.0)
#     890 """
#     891 Convert list of dicts to numpy arrays
#     892
#    (...)
#     907 columns : Index
#     908 """
#     909 if columns is None:
# --> 910     gen = (list(x.keys()) for x in data)
#     911     sort = not any(isinstance(d, dict) for d in data)
#     912     pre_cols = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
idx_af_bads = []
for idx, af in enumerate(audio_features):
    if af is None:
        idx_af_bads.append(idx)

print('Number of None values in audio features:', len(idx_af_bads))
# Out:
# Number of None values in audio features: 156

# %%
# Delete None values in audio_features before convert to DataFrame
audio_features = [af for af in audio_features if af is not None]
df_audio_features = pd.DataFrame(audio_features)
print('Shape audio features (without None values):', df_audio_features.shape)
df_audio_features.head()
# Out:
# Shape audio features (without None values): (276423, 18)
#    danceability  energy  key  loudness  mode  speechiness  acousticness
# 0         0.429   0.661   11    -7.227     1       0.0281       0.00239  \
# 1         0.315   0.715   11    -8.072     0       0.0362       0.00125
# 2         0.559   0.345    4   -13.496     1       0.0459       0.05760
# 3         0.472   0.671    4    -4.649     1       0.0290       0.01290
# 4         0.560   0.595    9    -4.530     1       0.0274       0.19900
#
#    instrumentalness  liveness  valence    tempo            type
# 0          0.000121    0.2340   0.2850  173.372  audio_features  \
# 1          0.000008    0.0942   0.4970  155.925  audio_features
# 2          0.000105    0.1410   0.4580   84.581  audio_features
# 3          0.000000    0.1590   0.0681   82.952  audio_features
# 4          0.000065    0.1320   0.1440  104.011  audio_features
#
#                        id                                   uri
# 0  3AJwUDP919kvQ9QcozQPxg  spotify:track:3AJwUDP919kvQ9QcozQPxg  \
# 1  6Qyc6fS4DsZjB2mRW9DsQs  spotify:track:6Qyc6fS4DsZjB2mRW9DsQs
# 2  3d9DChrdc6BOeFsbrZ3Is0  spotify:track:3d9DChrdc6BOeFsbrZ3Is0
# 3  77loZpT5Y5PRP1S451P9Yz  spotify:track:77loZpT5Y5PRP1S451P9Yz
# 4  5hnyJvgoWiQUYZttV4wXy6  spotify:track:5hnyJvgoWiQUYZttV4wXy6
#
#                                           track_href
# 0  https://api.spotify.com/v1/tracks/3AJwUDP919kv...  \
# 1  https://api.spotify.com/v1/tracks/6Qyc6fS4DsZj...
# 2  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 3  https://api.spotify.com/v1/tracks/77loZpT5Y5PR...
# 4  https://api.spotify.com/v1/tracks/5hnyJvgoWiQU...
#
#                                         analysis_url  duration_ms
# 0  https://api.spotify.com/v1/audio-analysis/3AJw...       266773  \
# 1  https://api.spotify.com/v1/audio-analysis/6Qyc...       289533
# 2  https://api.spotify.com/v1/audio-analysis/3d9D...       264307
# 3  https://api.spotify.com/v1/audio-analysis/77lo...       232800
# 4  https://api.spotify.com/v1/audio-analysis/5hny...       267960
#
#    time_signature
# 0               4
# 1               3
# 2               4
# 3               4
# 4               4

# %%
# Save df_audio_features to csv
df_audio_features.to_csv('./datasets/audio_features.csv', index=False)

# %%
# Merge dataframes df_tracks and df_audio_features
df_tracks_audio_features = pd.merge(
    df_tracks,
    df_audio_features,
    on="id",
    how="inner"
)
print(f'Shape audio features (after merge with tracks):', df_tracks_audio_features.shape)
df_tracks_audio_features.head()
# Out:
# Shape audio features (after merge with tracks): (276423, 22)
#                        id              name
# 0  3AJwUDP919kvQ9QcozQPxg            Yellow  \
# 1  6Qyc6fS4DsZjB2mRW9DsQs              Iris
# 2  3d9DChrdc6BOeFsbrZ3Is0  Under the Bridge
# 3  77loZpT5Y5PRP1S451P9Yz        The Reason
# 4  5hnyJvgoWiQUYZttV4wXy6      Chasing Cars
#
#                                         track_href_x
# 0  https://api.spotify.com/v1/tracks/3AJwUDP919kv...  \
# 1  https://api.spotify.com/v1/tracks/6Qyc6fS4DsZj...
# 2  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 3  https://api.spotify.com/v1/tracks/77loZpT5Y5PR...
# 4  https://api.spotify.com/v1/tracks/5hnyJvgoWiQU...
#
#                                album_name                album_id
# 0                              Parachutes  6ZG5lRT77aJ3btmArcykra  \
# 1                       Dizzy up the Girl  4UMjBXcRqIgMZ1XumU2x5T
# 2  Blood Sugar Sex Magik (Deluxe Edition)  30Perjew8HyGkdSmqguYyg
# 3    The Reason (15th Anniversary Deluxe)  2zE1YKY7Okj10Tjl09jjth
# 4                               Eyes Open  3k7bXPw2u0C0SBKPMsgMS3
#
#    danceability  energy  key  loudness  mode  ...  instrumentalness  liveness
# 0         0.429   0.661   11    -7.227     1  ...          0.000121    0.2340  \
# 1         0.315   0.715   11    -8.072     0  ...          0.000008    0.0942
# 2         0.559   0.345    4   -13.496     1  ...          0.000105    0.1410
# 3         0.472   0.671    4    -4.649     1  ...          0.000000    0.1590
# 4         0.560   0.595    9    -4.530     1  ...          0.000065    0.1320
#
#    valence    tempo            type                                   uri
# 0   0.2850  173.372  audio_features  spotify:track:3AJwUDP919kvQ9QcozQPxg  \
# 1   0.4970  155.925  audio_features  spotify:track:6Qyc6fS4DsZjB2mRW9DsQs
# 2   0.4580   84.581  audio_features  spotify:track:3d9DChrdc6BOeFsbrZ3Is0
# 3   0.0681   82.952  audio_features  spotify:track:77loZpT5Y5PRP1S451P9Yz
# 4   0.1440  104.011  audio_features  spotify:track:5hnyJvgoWiQUYZttV4wXy6
#
#                                         track_href_y
# 0  https://api.spotify.com/v1/tracks/3AJwUDP919kv...  \
# 1  https://api.spotify.com/v1/tracks/6Qyc6fS4DsZj...
# 2  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 3  https://api.spotify.com/v1/tracks/77loZpT5Y5PR...
# 4  https://api.spotify.com/v1/tracks/5hnyJvgoWiQU...
#
#                                         analysis_url duration_ms
# 0  https://api.spotify.com/v1/audio-analysis/3AJw...      266773  \
# 1  https://api.spotify.com/v1/audio-analysis/6Qyc...      289533
# 2  https://api.spotify.com/v1/audio-analysis/3d9D...      264307
# 3  https://api.spotify.com/v1/audio-analysis/77lo...      232800
# 4  https://api.spotify.com/v1/audio-analysis/5hny...      267960
#
#   time_signature
# 0              4
# 1              3
# 2              4
# 3              4
# 4              4
#
# [5 rows x 22 columns]

# %%
# Drop track_href_x column and rename track_href_y to track_href
df_tracks_audio_features.drop(columns=["track_href_x"], inplace=True)
df_tracks_audio_features.rename(columns={"track_href_y": "track_href"}, inplace=True)

# %%
# Save df_tracks_audio_features to csv
df_tracks_audio_features.to_csv('./datasets/tracks_audio_features.csv', index=False)

# %%
import os
from dotenv import load_dotenv
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

from utils.etl import get_playlist_info, get_track_info, get_tracks_from_playlists

# %%
genres_seeds = [
    "acoustic", "afrobeat", "alt-rock", "alternative", "ambient", "anime", "black-metal", 
    "bluegrass", "blues", "bossanova", "brazil", "breakbeat", "british", "cantopop", 
    "chicago-house", "children", "chill", "classical", "club", "comedy", "country", "dance", 
    "dancehall", "death-metal", "deep-house", "detroit-techno", "disco", "disney", 
    "drum-and-bass", "dub", "dubstep", "edm", "electro", "electronic", "emo", "folk", "forro", 
    "french", "funk", "garage", "german", "gospel", "goth", "grindcore", "groove", "grunge", 
    "guitar", "happy", "hard-rock", "hardcore", "hardstyle", "heavy-metal", "hip-hop", "holidays", 
    "honky-tonk", "house", "idm", "indian", "indie", "indie-pop", "industrial", "iranian", 
    "j-dance", "j-idol", "j-pop", "j-rock", "jazz", "k-pop", "kids", "latin", "latino", "malay", 
    "mandopop", "metal", "metal-misc", "metalcore", "minimal-techno", "movies", "mpb", "new-age", 
    "new-release", "opera", "pagode", "party", "philippines-opm", "piano", "pop", "pop-film", 
    "post-dubstep", "power-pop", "progressive-house", "psych-rock", "punk", "punk-rock", "r-n-b", 
    "rainy-day", "reggae", "reggaeton", "road-trip", "rock", "rock-n-roll", "rockabilly", "romance", 
    "sad", "salsa", "samba", "sertanejo", "show-tunes", "singer-songwriter", "ska", "sleep", 
    "songwriter", "soul", "soundtracks", "spanish", "study", "summer", "swedish", "synth-pop", 
    "tango", "techno", "trance", "trip-hop", "turkish", "work-out", "world-music"
]

# %%
# Spotify API credentials
load_dotenv()
client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')

# %%
# Spotify API authentication
client_credentials_manager = SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret
)
sp = spotipy.Spotify(
    client_credentials_manager=client_credentials_manager
)

# %%
# Search playlists by genre
# TODO: Convert to function
playlists_data = sp.search(q='alt-rock', type='playlist', limit=50, offset=0)
playlists = [
    get_playlist_info(playlist)
    for playlist in playlists_data['playlists']['items']
]
df_playlists = pd.DataFrame(playlists)
print(df_playlists.shape)
df_playlists.head()
# Out:
# (50, 4)
#                        id                   name
# 0  5W9dGuMEjLuSMmCgaYzIol               Alt rock  \
# 1  37i9dQZF1EIefLxrHQP8p4   Alternative Rock Mix
# 2  37i9dQZF1DX9GRpeH4CL0S  Essential Alternative
# 3  6UkcmQf7tYlGKX18IL8cyd              alt rock
# 4  37i9dQZF1DXa6YOhGMjjgx  New  Alt-Rock Mixtape
#
#                                          tracks_href
# 0  https://api.spotify.com/v1/playlists/5W9dGuMEj...  \
# 1  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 2  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 3  https://api.spotify.com/v1/playlists/6UkcmQf7t...
# 4  https://api.spotify.com/v1/playlists/37i9dQZF1...
#
#                                           main_image
# 0  https://mosaic.scdn.co/640/ab67616d0000b273038...
# 1  https://seed-mix-image.spotifycdn.com/v6/img/d...
# 2  https://i.scdn.co/image/ab67706f00000003437bdc...
# 3  https://mosaic.scdn.co/640/ab67616d0000b2730a8...
# 4  https://i.scdn.co/image/ab67706f00000003e00b16...

# %%
df_playlists["id"].isna().value_counts()
# Out:
# id
# False    50
# Name: count, dtype: int64

# %%
# Get tracks from playlists
tracks_playlists = get_tracks_from_playlists(playlists=df_playlists, sp=sp)
df_tracks = pd.DataFrame(tracks_playlists)
print(df_tracks.shape)
df_tracks.head()
# Out:
# (4313, 5)
#                        id               name
# 0  6L89mwZXSOwYl76YXfX13s        Basket Case  \
# 1  48UPSzbZjgc449aqz8bxox    Californication
# 2  5UWwZ5lm5PKu6eKsHAGxOk           Everlong
# 3  42et6fnHCw1HIPSrdPprMl  Semi-Charmed Life
# 4  04w73SmPfQkkmEpKbcrHOL       Heaven Knows
#
#                                           track_href
# 0  https://api.spotify.com/v1/tracks/6L89mwZXSOwY...  \
# 1  https://api.spotify.com/v1/tracks/48UPSzbZjgc4...
# 2  https://api.spotify.com/v1/tracks/5UWwZ5lm5PKu...
# 3  https://api.spotify.com/v1/tracks/42et6fnHCw1H...
# 4  https://api.spotify.com/v1/tracks/04w73SmPfQkk...
#
#                          album_name                album_id
# 0                            Dookie  4uG8q3GPuWHQlRbswMIRS6
# 1  Californication (Deluxe Edition)  2Y9IRtehByVkegoD7TcLfi
# 2          The Colour And The Shape  30ly6F6Xl0TKmyBCU50Khv
# 3                   Third Eye Blind  2gToC0XAblE9h3UZD6aAaQ
# 4    Going To Hell (Deluxe Edition)  2PYeB2ZxvfvPsEpd951xP4

# %%
df_tracks["id"].isna().value_counts()
# Out:
# id
# False    4311
# True        2
# Name: count, dtype: int64

# %%
# Delete rows with null values
df_tracks.dropna(inplace=True)
df_tracks["id"].isna().value_counts()
# Out:
# id
# False    4311
# Name: count, dtype: int64

# %%
# Delete duplicates by id
df_tracks.drop_duplicates(subset=["id"], inplace=True)
df_tracks.shape
# Out:
# (3414, 5)

# %%
# Get audio features from tracks
audio_features = []

for n in range(len(df_tracks) // 100 + 1):
    print('🟦', end='')
    df_tracks_pack = df_tracks.iloc[0 + 100 * n:100 + 100 * n]
    audio_features_pack = sp.audio_features(tracks=list(df_tracks_pack["id"]))
    audio_features += audio_features_pack

df_audio_features = pd.DataFrame(audio_features)
print()
print(df_audio_features.shape)
df_audio_features.head()
# Out:
# 🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦🟦
# (3414, 18)
#    danceability  energy  key  loudness  mode  speechiness  acousticness
# 0         0.442   0.943    3    -3.205     1       0.0602       0.00293  \
# 1         0.592   0.767    9    -2.788     0       0.0270       0.00210
# 2         0.413   0.881   11    -5.541     0       0.0367       0.00006
# 3         0.640   0.864    7    -6.576     1       0.0314       0.00832
# 4         0.543   0.815    2    -3.712     1       0.0439       0.07800
#
#    instrumentalness  liveness  valence    tempo            type
# 0          0.000009    0.0910    0.781   85.064  audio_features  \
# 1          0.001650    0.1270    0.328   96.483  audio_features
# 2          0.000308    0.0805    0.364  158.066  audio_features
# 3          0.000000    0.1230    0.701  102.026  audio_features
# 4          0.000000    0.2100    0.579   83.992  audio_features
#
#                        id                                   uri
# 0  6L89mwZXSOwYl76YXfX13s  spotify:track:6L89mwZXSOwYl76YXfX13s  \
# 1  48UPSzbZjgc449aqz8bxox  spotify:track:48UPSzbZjgc449aqz8bxox
# 2  5UWwZ5lm5PKu6eKsHAGxOk  spotify:track:5UWwZ5lm5PKu6eKsHAGxOk
# 3  42et6fnHCw1HIPSrdPprMl  spotify:track:42et6fnHCw1HIPSrdPprMl
# 4  04w73SmPfQkkmEpKbcrHOL  spotify:track:04w73SmPfQkkmEpKbcrHOL
#
#                                           track_href
# 0  https://api.spotify.com/v1/tracks/6L89mwZXSOwY...  \
# 1  https://api.spotify.com/v1/tracks/48UPSzbZjgc4...
# 2  https://api.spotify.com/v1/tracks/5UWwZ5lm5PKu...
# 3  https://api.spotify.com/v1/tracks/42et6fnHCw1H...
# 4  https://api.spotify.com/v1/tracks/04w73SmPfQkk...
#
#                                         analysis_url  duration_ms
# 0  https://api.spotify.com/v1/audio-analysis/6L89...       181533  \
# 1  https://api.spotify.com/v1/audio-analysis/48UP...       329733
# 2  https://api.spotify.com/v1/audio-analysis/5UWw...       250547
# 3  https://api.spotify.com/v1/audio-analysis/42et...       268360
# 4  https://api.spotify.com/v1/audio-analysis/04w7...       224533
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
# Merge dataframes df_tracks and df_audio_features
df_tracks_audio_features = pd.merge(
    df_tracks,
    df_audio_features,
    left_on="id",
    right_on="id",
    how="inner"
)
print(df_tracks_audio_features.shape)
df_tracks_audio_features.head()
# Out:
# (3414, 22)
#                        id               name
# 0  6L89mwZXSOwYl76YXfX13s        Basket Case  \
# 1  48UPSzbZjgc449aqz8bxox    Californication
# 2  5UWwZ5lm5PKu6eKsHAGxOk           Everlong
# 3  42et6fnHCw1HIPSrdPprMl  Semi-Charmed Life
# 4  04w73SmPfQkkmEpKbcrHOL       Heaven Knows
#
#                                         track_href_x
# 0  https://api.spotify.com/v1/tracks/6L89mwZXSOwY...  \
# 1  https://api.spotify.com/v1/tracks/48UPSzbZjgc4...
# 2  https://api.spotify.com/v1/tracks/5UWwZ5lm5PKu...
# 3  https://api.spotify.com/v1/tracks/42et6fnHCw1H...
# 4  https://api.spotify.com/v1/tracks/04w73SmPfQkk...
#
#                          album_name                album_id  danceability
# 0                            Dookie  4uG8q3GPuWHQlRbswMIRS6         0.442  \
# 1  Californication (Deluxe Edition)  2Y9IRtehByVkegoD7TcLfi         0.592
# 2          The Colour And The Shape  30ly6F6Xl0TKmyBCU50Khv         0.413
# 3                   Third Eye Blind  2gToC0XAblE9h3UZD6aAaQ         0.640
# 4    Going To Hell (Deluxe Edition)  2PYeB2ZxvfvPsEpd951xP4         0.543
#
#    energy  key  loudness  mode  ...  instrumentalness  liveness  valence
# 0   0.943    3    -3.205     1  ...          0.000009    0.0910    0.781  \
# 1   0.767    9    -2.788     0  ...          0.001650    0.1270    0.328
# 2   0.881   11    -5.541     0  ...          0.000308    0.0805    0.364
# 3   0.864    7    -6.576     1  ...          0.000000    0.1230    0.701
# 4   0.815    2    -3.712     1  ...          0.000000    0.2100    0.579
#
#      tempo            type                                   uri
# 0   85.064  audio_features  spotify:track:6L89mwZXSOwYl76YXfX13s  \
# 1   96.483  audio_features  spotify:track:48UPSzbZjgc449aqz8bxox
# 2  158.066  audio_features  spotify:track:5UWwZ5lm5PKu6eKsHAGxOk
# 3  102.026  audio_features  spotify:track:42et6fnHCw1HIPSrdPprMl
# 4   83.992  audio_features  spotify:track:04w73SmPfQkkmEpKbcrHOL
#
#                                         track_href_y
# 0  https://api.spotify.com/v1/tracks/6L89mwZXSOwY...  \
# 1  https://api.spotify.com/v1/tracks/48UPSzbZjgc4...
# 2  https://api.spotify.com/v1/tracks/5UWwZ5lm5PKu...
# 3  https://api.spotify.com/v1/tracks/42et6fnHCw1H...
# 4  https://api.spotify.com/v1/tracks/04w73SmPfQkk...
#
#                                         analysis_url duration_ms
# 0  https://api.spotify.com/v1/audio-analysis/6L89...      181533  \
# 1  https://api.spotify.com/v1/audio-analysis/48UP...      329733
# 2  https://api.spotify.com/v1/audio-analysis/5UWw...      250547
# 3  https://api.spotify.com/v1/audio-analysis/42et...      268360
# 4  https://api.spotify.com/v1/audio-analysis/04w7...      224533
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
#
# [5 rows x 22 columns]
